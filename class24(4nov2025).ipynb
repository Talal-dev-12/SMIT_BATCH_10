# %%
f = open('testing1.txt', 'r+')

# %%
f = open("newfile.txt", "r")
text =  f.read()
print(text)
f.close()
# Out:
# I am using context manager ALI KHAN
#
#
# talal is my daddy

# %%
f = open("myfile.txt", "w")
text = "My Name is  TAlal Nadeem"
f.write(text)
f.close()

# %%
f = open("myfile.txt", "a")
f.write("\nI am appending this line.")
f.close()

# %%
f.write('pakistan')
# Out:
# 8

# %%
f.read()
# Out:
# 'hir se contenti am using append plus modenaya content'

# %%
f.close()

# %%
f = open('testing1.txt', 'w+')

# %%
f.write('naya content')
# Out:
# 12

# %%
f.seek(0)
# Out:
# 0

# %%
f.read()
# Out:
# 'naya content'

# %%
f.close()

# %%
f = open('testing1.txt', 'a+')

# %%
f.seek(0)
# Out:
# 0

# %%
f.read()
# Out:
# 'ek bar phir se contenti am using append plus mode'

# %%
f.write('i am using append plus mode')
# Out:
# 27

# %%
f.close()

# %% [markdown]
# - r+:
#     - file should exists
#     - can use read and write both
#
# - w+:
#     - work similarily to normal write mode
#     - can use read and write both
#
# - a+:
#     - work similarily to normal append mode
#     - can use read and write both

# %% [markdown]
# # Context Manager(with)

# %%
# f------alias
with open('testing1.txt') as f:
    content = f.read()

# %%
content
# Out:
# 'new content'

# %%
with open('newfile.txt', 'w+') as f:
    f.write('I am using context manager')
    f.seek(0)
    content = f.read()

# %%
content
# Out:
# 'I am using context manager'

# %%
with open('newfile.txt', 'w') as f:
    f.write('I am using context manager')
    f.seek(0)
    content = f.read()
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11220\1806329741.py in <module>
#       2     f.write('I am using context manager')
#       3     f.seek(0)
# ----> 4     content = f.read()
#
# UnsupportedOperation: not readable

# %%
with open('testing1.txt', 'a+') as f:
    f.seek(0)
    content = f.read()

# %%
open('testing1.txt',"w").write("Fuck you beetch")
# Out:
# 15

# %%
with open("testing1.txt" , "r") as file:
    print(file.read())
# Out:
# Fuck you beetch
# Fuck you beetch

# %%
content
# Out:
# 'new content'

# %%
content = ""
with open('testing12.txt', "r") as f:
    content = f.read()
    
with open("testing12.txt" , "w") as f:
    writting_content = "Talal Daddy "+content
    f.write(writting_content)

with open("testing12.txt" , "r") as file:
    print(file.read())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[36], line 9
#       6     writting_content = "Talal Daddy "+content
#       7     f.write(writting_content)
# ----> 9 with open("testing12" , "r") as file:
#      10     print(file.read())
#
# File ~\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'testing12'

# %%
content
# Out:
# ''
