# %% [markdown]
# # Nested for loop

# %%
for i in range(1,11):
    print(f'2 x {i} = {2*i}')

# %%
colors = ["Red", "Blue"]
sizes = ["Small", "Medium", "Large"]

for color in colors:
    for size in sizes:
        print(f'size : {size}, color: {color}')


# size : Small, color: Red
# size : Medium, color: Red
# size : Large, color: Red
# size : Small, color: Blue
# size : Medium, color: Blue
# size : Large, color: Blue
# Out:
# size : Small, color: Red
# size : Medium, color: Red
# size : Large, color: Red
# size : Small, color: Blue
# size : Medium, color: Blue
# size : Large, color: Blue

# %%
# print those city/cities having all characters unique (not repetitive)
cities = ['Karachi', 'Lahore', 'Quetta', 'Dadu', 'Murre']

# %%
for city in cities:
    charcount = True
    for char in city:
        if city.lower().count(char) > 1:
            charcount = False
            break
    # if charcount == True:
    if charcount:
        print(city)
# Out:
# Lahore

# %%
for city in cities:
    empty_set = set()    
    for char in city.lower():
        empty_set.add(char)
    if len(empty_set) == len(city):
        print(city)
# Out:
# Lahore

# %% [markdown]
# # While Loop

# %%
flag = True
# while condition
while flag:
    country = input('Enter your country name: ').lower()
    country = country[:8]
    if country == 'pakistan':
        print('You are eligible for cnic')
        flag = False
    else:
        print(f'This country {country} is not eligible')
# Out:
# You are eligible for cnic

# %%
length = float(input('Enter length'))
width = float(input('Enter width'))

if length == width:
    print(length * width)
else:
    print(2 * (length + width))

# %%
def apna_function():
    print('This is my function')
    print('This is my function')
    print('This is my function')

apna_function()
# Out:
# This is my function
# This is my function
# This is my function

# %%
def get_cities():
    cities = ['Karachi', 'Lahore', 'Quetta', 'Dadu', 'Murre']
    return cities

print(get_cities())

def Aghani_Bharway():
    country = input('Enter your country name: ').lower()
    country = country[:12]
    if country == 'afghanistan':
        print('Bharway namak Haram')
    else:
        print(f'This country {country} is good to live ')
        
Aghani_Bharway()
# Out:
# ['Karachi', 'Lahore', 'Quetta', 'Dadu', 'Murre']
# This country pakistan is good to live

# %%
def area_or_perimeter(length, width):
    if length == width:
        return length * width
    else:
        return 2 * (length + width)
    
print(area_or_perimeter(4,5))
# Out:
# 18

# %%
cities = ['Karachi', 'Lahore', 'Quetta', 'Dadu', 'Murre']
def print_cities(shars):    
    for shahar in shars:
        print(shahar)
    
print_cities(cities)
# Out:
# Karachi
# Lahore
# Quetta
# Dadu
# Murre

# %%
def sum(num1,num2):
    result = num1 + num2
    return result
    
result1 = sum(5,6)
result2 = sum(10,100)

print(result1)
print(result2)
# Out:
# 11
# 110

# %%
def get_even_odd(numbers):
    even = []
    odd =[] 
    for
